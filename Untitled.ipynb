# %%
import pandas as pd

# %%
df = pd.read_csv('dataCSV.csv')
train = pd.read_csv('train.csv')
df.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0            7       1710           2         548          856       856
# 1            6       1262           2         460         1262      1262
# 2            7       1786           2         608          920       920
# 3            7       1717           3         642          756       961
# 4            8       2198           3         836         1145      1145
#
#    FullBath  YearBuilt  YearRemodAdd  TotRmsAbvGrd  MasVnrArea  Fireplaces  \
# 0         2       2003          2003             8       196.0           0
# 1         2       1976          1976             6         0.0           1
# 2         2       2001          2002             6       162.0           1
# 3         1       1915          1970             7         0.0           1
# 4         2       2000          2000             9       350.0           1
#
#    BsmtFinSF1  KitchenQual  ExterQual  BsmtQual  HeatingQC  SalePrice
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
#        '1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd',
#        'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'KitchenQual', 'ExterQual',
#        'BsmtQual', 'HeatingQC', 'SalePrice'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
num = []
for val in df['OverallQual']:
    if val == 1:
        num.append('Very Poor')
    elif val == 2:
        num.append('Poor')
    elif val == 3:
        num.append('Fair')
    elif val == 4:
        num.append('Below Average')
    elif val == 5:
        num.append('Average')
    elif val == 6:
        num.append('Above Average')
    elif val == 7:
        num.append('Good')
    elif val == 8:
        num.append('Very Good')
    elif val == 9:
        num.append('Excellent')
    elif val == 10:
        num.append('very Excellent')
df['OverallQual'] = pd.Series(num)

# %%
df.head()
# Out:
#      OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0           Good       1710           2         548          856       856
# 1  Above Average       1262           2         460         1262      1262
# 2           Good       1786           2         608          920       920
# 3           Good       1717           3         642          756       961
# 4      Very Good       2198           3         836         1145      1145
#
#    FullBath  YearBuilt  YearRemodAdd  TotRmsAbvGrd  MasVnrArea  Fireplaces  \
# 0         2       2003          2003             8       196.0           0
# 1         2       1976          1976             6         0.0           1
# 2         2       2001          2002             6       162.0           1
# 3         1       1915          1970             7         0.0           1
# 4         2       2000          2000             9       350.0           1
#
# ...

# %%
for col in df.columns:
    print(df[col].value_counts().sort_index())
# Out:
# Above Average     364
# Average           381
# Below Average     112
# Excellent          39
# Fair               20
# Good              314
# Poor                3
# Very Good         160
# Very Poor           2
# very Excellent     11
# Name: OverallQual, dtype: int64
# 334     1
# 438     1
# 480     1
# 520     1
# 605     1
# 616     1
# 630     6
# 672     2
# 691     1
# 693     1
# 694     1
# 698     1
# 708     1
# 720     3
# 729     1
# 747     2
# 752     1
# 754     1
# 764     1
# 767     1
# 768     3
# 773     1
# 774     1
# 778     1
# 780     1
# 784     2
# 788     1
# 789     2
# 790     1
# 792     1
#        ..
# 2612    1
# 2614    1
# 2622    1
# 2624    1
# 2630    1
# 2633    1
# 2640    1
# 2643    1
# 2646    1
# 2654    1
# 2668    1
# 2696    1
# 2704    1
# 2713    1
# 2727    1
# 2728    1
# 2730    1
# 2775    1
# 2794    1
# 2810    1
# 2828    1
# 2868    1
# 2872    1
# 2945    1
# 2978    1
# 3140    1
# 3194    1
# 3222    1
# 3238    1
# ...

# %%
for col in ['KitchenQual','ExterQual','BsmtQual','HeatingQC']:
    print(train[col].value_counts().sort_index())
# Out:
# Ex    100
# Fa     39
# Gd    586
# TA    735
# Name: KitchenQual, dtype: int64
# Ex     52
# Fa     14
# Gd    488
# TA    906
# Name: ExterQual, dtype: int64
# Ex    121
# Fa     35
# Gd    618
# TA    649
# Name: BsmtQual, dtype: int64
# Ex    741
# Fa     49
# Gd    241
# Po      1
# TA    428
# Name: HeatingQC, dtype: int64

# %%
num = []
for col in ['KitchenQual','ExterQual']:
    for val in df[col]:
        if val == 0:
            num.append('Excellent')
        elif val == 1:
            num.append('Fair')
        elif val == 2:
            num.append('Good')
        elif val == 3:
            num.append('Average')
    df[col] = pd.Series(num)
    num = []

# %%
num = []
for val in df['BsmtQual']:
    if val == 0:
        num.append('Excellent')
    elif val == 1:
        num.append('Fair')
    elif val == 2:
        num.append('Good')
    elif val == 3:
        num.append('None')
    elif val == 4:
        num.append('Average')
df['BsmtQual'] = pd.Series(num)

# %%
num = []
for val in df['HeatingQC']:
    if val == 0:
        num.append('Excellent')
    elif val == 1:
        num.append('Fair')
    elif val == 2:
        num.append('Good')
    elif val == 3:
        num.append('Poor')
    elif val == 4:
        num.append('Average')
df['HeatingQC'] = pd.Series(num)

# %%
for col in ['KitchenQual','ExterQual','BsmtQual','HeatingQC']:
    print(df[col].value_counts().sort_index())
# Out:
# Average      711
# Excellent     87
# Fair          36
# Good         572
# Name: KitchenQual, dtype: int64
# Average      876
# Excellent     42
# Fair          12
# Good         476
# Name: ExterQual, dtype: int64
# Average      623
# Excellent    110
# Fair          33
# Good         606
# None          34
# Name: BsmtQual, dtype: int64
# Average      413
# Excellent    713
# Fair          47
# Good         232
# Poor           1
# Name: HeatingQC, dtype: int64

# %%
df.head()
# Out:
#      OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0           Good       1710           2         548          856       856
# 1  Above Average       1262           2         460         1262      1262
# 2           Good       1786           2         608          920       920
# 3           Good       1717           3         642          756       961
# 4      Very Good       2198           3         836         1145      1145
#
#    FullBath  YearBuilt  YearRemodAdd  TotRmsAbvGrd  MasVnrArea  Fireplaces  \
# 0         2       2003          2003             8       196.0           0
# 1         2       1976          1976             6         0.0           1
# 2         2       2001          2002             6       162.0           1
# 3         1       1915          1970             7         0.0           1
# 4         2       2000          2000             9       350.0           1
#
# ...

# %%
df.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
#        '1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd',
#        'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'KitchenQual', 'ExterQual',
#        'BsmtQual', 'HeatingQC', 'SalePrice'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 18

# %%
sorted(df['KitchenQual'].unique())
# Out:
# ['Average', 'Excellent', 'Fair', 'Good']

# %%
x = [[11,22,33,455,488,66,666,65848]]
dfX = pd.DataFrame(x)
dfX
# Out:
#     0   1   2    3    4   5    6      7
# 0  11  22  33  455  488  66  666  65848

# %%
df.to_csv('dataDashboard.csv')

# %%
df[((df['GarageCars'] >= int(garage[0])) & (df['GarageCars'] <= int(garage[1]))) |
   ((df['FullBath'] >= int(bathroom[0])) & (df['FullBath'] <= int(bathroom[1]))) |
   ((df['TotRmsAbvGrd'] >= int(room[0])) & (df['TotRmsAbvGrd'] <= int(room[1]))) |
   ((df['Fireplaces'] >= int(fireplace[0])) & (df['Fireplaces'] <= int(fireplace[1]))) |
   ((df['GrLivArea'] >= int(area[0])) & (df['GrLivArea'] <= int(area[1]))) |
   ((df['YearBuilt'] >= int(year[0])) & (df['YearBuilt'] <= int(year[1]))) |
   ((df['SalePrice'] >= int(price[0])) & (df['SalePrice'] <= int(price[1])))]
